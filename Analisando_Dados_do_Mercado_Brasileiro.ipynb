# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelresende/MercadoFinanceiroBr/blob/main/Analisando_Dados_do_Mercado_Brasileiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install investpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 32.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for investpy: filename=investpy-1.0.8-py3-none-any.whl size=4481564 sha256=bf732bf84403ba47bdd90073d2eff0e97bd475b564a814c550cd5a0c2abbf42d
#   Stored in directory: /root/.cache/pip/wheels/df/e8/50/8d6a7119bc8829b70c66573d84e09873d611f9244cf5a1d1b2
# Successfully built investpy
# ...

# %%
import yfinance as yf
import pandas as pd
import investpy as inv

# %%
br = inv.stocks.get_stocks(country='brazil')
br.head(5)
# Out:
#   country           name                               full_name  \
# 0  brazil  ABC BRASIL PN                     Banco ABC Brasil SA
# 1  brazil  BRASILAGRO ON                   BrasilAgro - Co ON NM
# 2  brazil     RUMO ON NM  RUMO Logistica Operadora Multimodal SA
# 3  brazil  ALPARGATAS ON                           Alpargatas SA
# 4  brazil  ALPARGATAS PN                           Alpargatas SA
#
#            isin currency symbol
# 0  BRABCBACNPR4      BRL  ABCB4
# 1  BRAGROACNOR7      BRL  AGRO3
# 2  BRRAILACNOR9      BRL  RAIL3
# 3  BRALPAACNOR0      BRL  ALPA3
# 4  BRALPAACNPR7      BRL  ALPA4
