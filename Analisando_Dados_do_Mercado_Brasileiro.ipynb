# %% [markdown]
# <a href="https://colab.research.google.com/github/rachelresende/MercadoFinanceiroBr/blob/main/Analisando_Dados_do_Mercado_Brasileiro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install investpy
# !pip install --upgrade pandas-datareader

# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt #graficos

import yfinance as yf
import investpy as inv
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

# %%
# Índice Ibovespa (^BVSP)
df_ibov = yf.download('^BVSP', start='2020-02-20', end='2021-02-20')
display(df_ibov)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2020-02-20  114586.0  116552.0  114379.0  116518.0   6793000
# 2020-02-21  113681.0  114585.0  112661.0  114585.0   5896200
# 2020-02-26  105718.0  113647.0  105053.0  113647.0   9369800
# 2020-02-27  102984.0  106656.0  102984.0  105711.0  11237700
# 2020-02-28  104172.0  104172.0   99951.0  102984.0  11228400
# ...              ...       ...       ...       ...       ...
# 2021-02-11  119235.0  120283.0  118440.0  118440.0   7567400
# 2021-02-12  119116.0  119763.0  118163.0  119300.0   7655900
# 2021-02-17  120391.0  120573.0  118880.0  119421.0   8326100
# 2021-02-18  119140.0  120845.0  118515.0  120361.0  10720600
# 2021-02-19  118748.0  119250.0  117867.0  119199.0  10402800
#
# [245 rows x 5 columns]

# %%
df_ibov["Close"].plot(figsize=(15, 10))
plt.show()

# %%
# (PETR4.SA)
df_petro = yf.download('^BVSP', start='2025-02-01', end='2025-02-20')
display(df_petro)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open    Volume
# Ticker         ^BVSP     ^BVSP     ^BVSP     ^BVSP     ^BVSP
# Date
# 2025-02-03  125970.0  126473.0  125566.0  126135.0   9548900
# 2025-02-04  125147.0  125964.0  124694.0  125964.0   9784500
# 2025-02-05  125534.0  125846.0  124637.0  125146.0   9957400
# 2025-02-06  126225.0  126399.0  125249.0  125531.0  10028600
# 2025-02-07  124619.0  126524.0  124320.0  126219.0  10952400
# 2025-02-10  125572.0  126386.0  124619.0  124619.0   8908600
# 2025-02-11  126522.0  126886.0  125570.0  125571.0  11242800
# 2025-02-12  124380.0  126513.0  124116.0  126513.0  14625100
# 2025-02-13  124850.0  124853.0  123778.0  124372.0   9048100
# 2025-02-14  128219.0  128482.0  124849.0  124849.0  12560100
# 2025-02-17  128869.0  129534.0  128229.0  128229.0   7032800
# 2025-02-18  128532.0  129294.0  128012.0  128553.0  10994100
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(df_petro['Close'])
plt.title('Cotação de Fechamento da PETR4')
plt.xlabel('Data')
plt.ylabel('Preço (R$)')
plt.grid(True)
plt.show()

# %%
sns.distplot(df_petro ['High'])
# Out:
# <ipython-input-48-8480c39ba728>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_petro ['High'])
# <Axes: ylabel='Density'>
